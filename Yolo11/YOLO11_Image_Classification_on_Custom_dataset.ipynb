# %%
# !pip install --upgrade ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.0/871.0 kB 46.4 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/Chicken-fecal-images.zip
# Out:
# Archive:  /content/Chicken-fecal-images.zip
#    creating: Chicken-fecal-images/
#    creating: Chicken-fecal-images/train/
#    creating: Chicken-fecal-images/train/Coccidiosis/
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.0.jpg
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.1.jpg
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.10.jpg
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.100.jpg
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.101.jpg
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.102.jpg
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.103.jpg
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.104.jpg
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.105.jpg
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.106.jpg
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.107.jpg
#   inflating: Chicken-fecal-images/train/Coccidiosis/cocci.108.jpg
# ...

# %%
from ultralytics import YOLO

#loading classification model
model = YOLO('yolo11n-cls.pt')

#train the model
results = model.train(data='/content/Chicken-fecal-images', epochs=20, imgsz=640)
# Out:
# ...
# 100%|██████████| 5.52M/5.52M [00:00<00:00, 368MB/s]
# Ultralytics 8.3.12 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # Inference

# %%
from IPython.display import Image

# %%
Image("/content/runs/classify/train/results.png", width=600)

# %%
model = YOLO('/content/runs/classify/train/weights/best.pt')

results = model("/content/cocci.0.jpg") #, save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/cocci.0.jpg: 640x640 Coccidiosis 1.00, Healthy 0.00, 5.5ms
# Speed: 12.8ms preprocess, 5.5ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
results = model("/content/healthy.0.jpg", save=True, conf=0.5)
results[0].show()
# Out:
# image 1/1 /content/healthy.0.jpg: 640x640 Healthy 1.00, Coccidiosis 0.00, 5.1ms
# Speed: 15.8ms preprocess, 5.1ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/classify/predict
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
results
# Out:
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: None
#  keypoints: None
#  masks: None
#  names: {0: 'Coccidiosis', 1: 'Healthy'}
#  obb: None
#  orig_img: array([[[120, 124, 135],
#          [126, 130, 141],
#          [122, 123, 137],
#          ...,
#          [107, 114, 131],
#          [ 98, 106, 123],
#          [115, 123, 140]],
#
#         [[118, 122, 133],
#          [122, 126, 137],
#          [117, 119, 130],
#          ...,
#          [114, 121, 140],
#          [116, 124, 141],
#          [117, 125, 142]],
#
#         [[109, 114, 123],
#          [113, 118, 127],
#          [114, 119, 128],
#          ...,
#          [154, 165, 185],
#          [126, 133, 152],
#          [107, 113, 132]],
#
#         ...,
#
#         [[ 75,  84,  87],
#          [ 81,  90,  93],
#          [107, 116, 119],
#          ...,
#          [159, 163, 168],
#          [160, 164, 169],
#          [145, 149, 154]],
#
#         [[157, 168, 172],
#          [169, 180, 184],
# ...
